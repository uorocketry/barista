# %%
# %matplotlib inline
from LogParser import LogParser
import matplotlib.pyplot as plt
plt.ion()

lp = LogParser()

df = lp.getXs('1522127760.log.sample', 'Acceleration')
df = df.set_index("Time")

# %%
# %matplotlib inline
df=df.astype(float)
df.plot()

# %%
df = lp.getYs('1522127760.log.sample', 'Acceleration')
df = df.set_index("Time")

# %matplotlib inline
df=df.astype(float)
df.plot()

# %%
df = lp.getZs('1522127760.log.sample', 'Position')
df = df.set_index("Time")

# %matplotlib inline
df=df.astype(float)
df.plot()
