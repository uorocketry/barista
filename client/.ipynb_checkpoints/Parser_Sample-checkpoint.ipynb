# %%
# %matplotlib inline
from LogParser import LogParser
import matplotlib.pyplot as plt
plt.ion()
plt.style.use('ggplot')
lp = LogParser()

# %%
# %matplotlib inline

plt.rcParams['figure.figsize'] = (25, 10)

df = lp.getXs('/home/anthony/Documents/uOStar/barista/app/logs/1522127760.log.sample', 'Velocity')

ax1 = df.plot()
plt.xlabel("Time", fontsize="24")
plt.ylabel("X Velocity (m/s^2)", fontsize="24")
# Out:
# Text(0,0.5,'X Velocity (m/s^2)')

# %%
df = lp.getYs('1522127760.log.sample', 'Velocity')
df = df.set_index("Time")

# %matplotlib inline
df=df.astype(float)
ax2 = df.plot()
ax2.autoscale()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-c457467ad620> in <module>()
# ----> 1 df = lp.getYs('1522127760.log.sample', 'Velocity')
#       2 df = df.set_index("Time")
#       3
#       4 get_ipython().magic(u'matplotlib inline')
#       5 df=df.astype(float)
#
# /home/anthony/Documents/uOStar/barista/client/LogParser.py in getYs(self, log_file, param)
#      49         value_pattern = r'(?<=y: )(-?\d*\.?\d*)'
#      50
# ---> 51         parse_file = open(log_file, 'r')
#      52
#      53         y_data = []
#
# IOError: [Errno 2] No such file or directory: '1522127760.log.sample'

# %%
df = lp.getZs('1522127760.log.sample', 'Acceleration')
df = df.set_index("Time")

# %matplotlib inline
df=df.astype(float)
ax3 = df.plot()
